# %%
import pandas as pd
import os

# %%
os.listdir()[0]
# Out:
# 'EmpiricalVariance.csv'

# %%
pre_data = os.listdir()[0]

# %%
pd.read_csv(pre_data)
# Out:
#            Unnamed: 0  Group 1  Group 2   diff  p_pool   SE_pool  d_cutoff
# 0   0.5 % Experiments    0.100    0.040  0.060   0.070  0.051029  0.100018
# 1   0.5 % Experiments    0.100    0.100  0.000   0.100  0.060000  0.117600
# 2   0.5 % Experiments    0.040    0.120 -0.080   0.080  0.054259  0.106347
# 3   0.5 % Experiments    0.140    0.080  0.060   0.110  0.062578  0.122653
# 4   0.5 % Experiments    0.000    0.100 -0.100   0.050  0.043589  0.085434
# 5   0.5 % Experiments    0.080    0.160 -0.080   0.120  0.064992  0.127385
# 6   0.5 % Experiments    0.180    0.120  0.060   0.150  0.071414  0.139972
# 7   0.5 % Experiments    0.080    0.200 -0.120   0.140  0.069397  0.136019
# 8   0.5 % Experiments    0.080    0.080  0.000   0.080  0.054259  0.106347
# 9   0.5 % Experiments    0.120    0.160 -0.040   0.140  0.069397  0.136019
# 10  0.5 % Experiments    0.060    0.060  0.000   0.060  0.047497  0.093095
# ...
